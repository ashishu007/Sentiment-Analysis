# %%
import nltk, re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
def filter_stopwords(sentence):
    example_sent = sentence
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(example_sent)
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    filtered_sentence = []
    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)
#     print(word_tokens)
#     print(filtered_sentence)
    return filtered_sentence

# %%
res = filter_stopwords("This is a sample sentence, showing off the stop words filtration.")
print(res)

# %%
def stemming_sent(sentence):
    ps = PorterStemmer()
    words = word_tokenize(sentence)
    stems = []
    for w in words:
        stems.append(ps.stem(w))
    return stems

def stemming_tokens(tokens):
    ps = PorterStemmer()
    stems = []
    for w in tokens:
        stems.append(ps.stem(w))
    return stems

# %%
res1 = stemming_sent("This is a sample sentence, showing off the stop words filtration.")
print(res1)
res2 = stemming_tokens(res)
print(res2)

# %%
# sample_text = state_union.raw("2006-GWBush.txt")
# custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
# tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content(sentence):
    train_text = state_union.raw("2005-GWBush.txt")
    custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
    tokenized = custom_sent_tokenizer.tokenize(sentence)
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)

            chunkGram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT|TO>+{"""

            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)

            chunked.draw()            
#             words = nltk.word_tokenize(i)
#             tagged = nltk.pos_tag(words)
#             print(tagged)

    except Exception as e:
        print(str(e))
    return tagged

# %%
sen = "This is a sample sentence, showing off the stop words filtration."
res3 = process_content(sen)
print(res3)

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized[5:]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            namedEnt = nltk.ne_chunk(tagged, binary=True)
            namedEnt.draw()
    except Exception as e:
        print(str(e))


# process_content()

# %%
def processTweet(tweet):
    # process the tweets

    #Convert to lower case
    tweet = tweet.lower()
    #Convert www.* or https?://* to URL
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','AT_USER',tweet)
    #Remove additional white spaces
    tweet = re.sub('[\s]+', ' ', tweet)
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    #trim
    tweet = tweet.strip('\'"')
    return tweet

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\User\\Sentiment-Analysis\\src\\main\\Resources\\trainingandtestdata\\testing_final.csv")
stops = []
for i in df["text"]:
    st = filter_stopwords(processTweet(i))
    # st = filter_stopwords(i)
    for j in st:
        stops.append(j)
        
print(stops)
# Out:
# ['loooooooovvvvvveee', 'kindle2', 'dx', 'cool', '2', 'fantastic', 'right', 'reading', 'kindle2', 'love', 'lee', 'childs', 'good', 'read', 'ok', 'first', 'assesment', 'kindle2', 'fucking', 'rocks', 'love', 'kindle2', 'mine', 'months', 'never', 'looked', 'back', 'new', 'big', 'one', 'huge', 'need', 'remorse', 'fair', 'enough', 'kindle2', 'think', 'perfect', 'big', 'quite', 'happy', 'kindle2', 'fuck', 'economy', 'hate', 'aig', 'non', 'loan', 'given', 'asses', 'jquery', 'new', 'best', 'friend', 'loves', 'twitter', 'love', 'obama', 'makes', 'jokes', 'check', 'video', 'president', 'obama', 'white', 'house', 'correspondents', 'dinner', 'firmly', 'believe', 'obama', 'pelosi', 'zero', 'desire', 'civil', 'charade', 'slogan', 'want', 'destroy', 'conservatism', 'house', 'correspondents', 'dinner', 'last', 'night', 'whoopi', 'barbara', 'amp', 'sherri', 'went', 'obama', 'got', 'standing', 'ovation', 'watchin', 'espn', 'jus', 'seen', 'new', 'nike', 'commerical', 'puppet', 'lebron', 'sh', 'hilarious', 'lmao', 'dear', 'nike', 'stop', 'flywire', 'shit', 'waste', 'science', 'ugly', 'love', 'lebron', 'best', 'athlete', 'generation', 'time', 'basketball', 'related', 'want', 'get', 'inter', 'sport', 'debates', '1', '2', 'talking', 'guy', 'last', 'night', 'telling', 'die', 'hard', 'spurs', 'fan', 'also', 'told', 'hates', 'lebron', 'james', 'love', 'lebron', 'lebron', 'beast', 'still', 'cheering', '4', 'til', 'end', 'lebron', 'boss', 'lebron', 'hometown', 'hero', 'lol', 'love', 'lakers', 'let', 'go', 'cavs', 'lol', 'lebron', 'zydrunas', 'awesome', 'duo', 'lebron', 'beast', 'nobody', 'nba', 'comes', 'even', 'close', 'downloading', 'apps', 'iphone', 'much', 'fun', 'literally', 'app', 'anything', 'good', 'news', 'call', 'visa', 'office', 'saying', 'everything', 'fine', 'relief', 'sick', 'scams', 'stealing', 'awesome', 'come', 'back', 'via', 'montreal', 'long', 'weekend', 'r', 'amp', 'r', 'much', 'needed', 'booz', 'allen', 'hamilton', 'bad', 'ass', 'homegrown', 'social', 'collaboration', 'platform', 'way', 'cool', 'ttiv', 'mluc09', 'customer', 'innovation', 'award', 'winner', 'booz', 'allen', 'hamilton', 'current', 'use', 'nikon', 'd90', 'love', 'much', 'canon', '40d', '50d', 'chose', 'd90', 'video', 'feature', 'mistake', 'need', 'suggestions', 'good', 'ir', 'filter', 'canon', '40d', 'got', 'pls', 'dm', 'checked', 'google', 'business', 'blip', 'shows', 'second', 'entry', 'huh', 'good', 'ba', 'google', 'always', 'good', 'place', 'look', 'mentioned', 'worked', 'mustang', 'w', 'dad', 'played', 'android', 'google', 'phone', 'slide', 'screen', 'scares', 'would', 'break', 'fucker', 'fast', 'still', 'prefer', 'iphone', 'us', 'planning', 'resume', 'military', 'tribunals', 'guantanamo', 'bay', 'time', 'trial', 'aig', 'execs', 'chrysler', 'debt', 'holders', 'omg', 'bored', 'amp', 'tattoooos', 'itchy', 'help', 'aha', 'itchy', 'miserable', 'itchy', 'maybe', 'later', 'lol', 'love', 'nerdy', 'stanford', 'human', 'biology', 'videos', 'makes', 'miss', 'school', 'bit', 'crazy', 'steep', 'learning', 'curve', 'lyx', 'really', 'good', 'long', 'docs', 'anything', 'shorter', 'would', 'insane', 'listening', 'p', 'danny', 'gokey', 'lt', '3', 'lt', '3', 'lt', '3', 'aww', 'amazing', 'lt', '3', 'much', 'going', 'sleep', 'bike', 'ride', 'cant', 'sleep', 'tooth', 'aching', 'blah', 'blah', 'blah', 'old', 'old', 'plans', 'today', 'going', 'back', 'sleep', 'guess', 'glad', 'didnt', 'bay', 'breakers', 'today', '1000', 'freaking', 'degrees', 'san', 'francisco', 'wtf', 'san', 'francisco', 'bay', 'breakers', 'landed', 'san', 'francisco', 'san', 'francisco', 'today', 'suggestions', 'obama', 'administration', 'must', 'stop', 'bonuses', 'aig', 'ponzi', 'schemers', 'started', 'think', 'citi', 'really', 'deep', 'amp', 'gon', 'na', 'survive', 'turmoil', 'gon', 'na', 'next', 'aig', 'shaunwoo', 'hate', 'n', 'aig', 'regret', 'going', 'see', 'star', 'trek', 'awesome', 'way', 'see', 'star', 'trek', 'esquire', 'going', 'see', 'star', 'trek', 'soon', 'dad', 'annoying', 'new', 'trend', 'internets', 'peo ...

# %%
set_stops = set(stops)
# s = list(set_stops)
for i in set_stops:
    print(i)
# Out:
# text
# dslr
# worst
# eh
# girlfriend
# climate
# days
# stiller
# mustang
# dissapointed
# program
# science
# facebook
# execs
# maybe
# needs
# fridge
# studing
# damn
# braindead
# plugin
# running
# esquire
# except
# epic
# fricken
# contract
# fuzzball
# rocks
# tamasha
# wrist
# fav
# dishonest
# mluc09
# nails
# bitten
# hummer
# coming
# pills
# death
# care
# 85mm
# india
# mostvaluablepuppets
# aww
# remorse
# hamilton
# whole
# ooooh
# rich
# psyop
# scary
# like
# phillies
# risotto
# murdering
# lack
# yeeeee
# www
# booz
# fitness
# pg
# blip
# dude
# wants
# american
# sashimi
# bullshit
# administration
# stupid
# avoided
# cease
# riddance
# cheap
# stacy
# trainer
# biden
# fees
# cute
# 10
# nbc
# nightmare
# dead
# physical
# gem
# cut
# platinum
# binhai
# winer
# tricks
# underestimated
# broccoli
# soul
# food
# ads
# java
# feed
# let
# popular
# gop
# add
# et
# wishing
# camera
# 4
# coca
# live
# butt
# slate
# tempted
# water
# realize
# klunky
# mosquito
# features
# internet
# mountain
# week
# fault
# aapl
# spinach
# real
# flockofseagullsweregeopoliticallycorrect
# stay
# missed
# n
# support
# singapore
# browser
# crippe
# appt
# arhh
# wwdc
# might
# 2012
# 1
# im
# bunch
# allen
# school
# propre
# fuin
# phil
# bitch
# wrong
# vote
# coupons
# biology
# argghhhh
# coordinates
# problems
# bummer
# roger
# apartment
# boyle
# gum
# shaunwoo
# created
# experience
# php
# healthy
# makes
# roll
# appointment
# pissed
# fortune
# cheney
# 3
# cs4
# mails
# bud
# cali
# lots
# thursday
# staples
# review
# cars
# beyond
# outliers
# absolutely
# internets
# dslreports
# together
# regular
# dave
# lost
# party
# srsly
# whoever
# f
# show
# release
# money
# tcot
# hate
# pelosi
# bell
# since
# til
# 5
# hard
# hero
# uaw
# resold
# omg
# investigation
# cunt
# computer
# scientist
# happy
# promotions
# sick
# mate
# screams
# price
# awful
# calcio1
# profit
# porn
# dime
# got
# link
# big
# freakin
# quaint
# 12
# market
# shame
# flywire
# undo
# implode
# dot
# financial
# brings
# years
# connections
# sad
# results
# gut
# nancy
# someone
# essay
# arg
# obsessed
# league
# 2moro
# 16209
# programming
# troubleeeee
# components
# even
# p
# many
# apps
# said
# need
# thinking
# must
# python
# talent
# alpha
# wikipedia
# idol
# believe
# com
# books
# told
# ima
# explain
# hit
# trouble
# skin
# well
# winner
# perfect
# loved
# rather
# holiday
# amphitheatre
# following
# data
# tlot
# south
# client
# oooooooh
# sucks
# peppers
# cheering
# course
# sorry
# prettiest
# stick
# slide
# mine
# imgsearch
# fish
# cnn
# katydids
# information
# tip
# breakers
# en
# bayes
# powerful
# 1st
# rocked
# nuggets
# pls
# naive
# amazing
# result
# cookbook
# speak
# premium
# programme
# bit
# today
# rajeev
# fucking
# nationalization
# break
# girl
# commercials
# yummmmmy
# ball
# webapp
# yr
# trek
# ahhh
# advance
# siding
# lhu
# fml
# bye
# runner
# buildin
# get
# drive
# nvidia
# ughh
# announcement
# loan
# james
# verse
# barack
# ap
# governments
# 6pm
# crap
# hope
# charade
# huh
# dum
# tv
# playoffs
# lawnmowing
# app
# billups
# tomorrow
# find
# ummm
# public
# social
# put
# whose
# dearest
# assholes
# giants
# picks
# bob
# spx
# ea
# worked
# reference
# tipping
# useless
# snap
# np
# next
# visualization
# innovation
# everything
# obama
# upside
# select
# hardly
# brush
# please
# 200
# hates
# bad
# prefer
# natural
# left
# kitchen
# awake
# electronic
# available
# family
# gps
# everyone
# dunk
# ever
# voice
# released
# bt
# sports
# popularity
# baseballamerica
# broken
# feel
# pink
# conservatism
# campaign
# terrifying
# expires
# ovation
# eat
# outs
# highly
# players
# heads
# swithsonian
# dropped
# head
# inkscape
# nerd
# work
# slowly
# judd
# jobs
# hours
# load
# piano
# highlight
# brand
# human
# acia
# animations
# geldof
# giggling
# members
# lyx
# guy
# one
# new
# blows
# church
# weekend
# teach
# custom
# funfun
# dear
# scrapbooking
# plans
# correspondents
# loving
# cracka
# iphone
# period
# niggas
# disaster
# prob
# pair
# enjoy
# remote
# stealing
# online
# comment
# blog
# hu
# geekiness
# beijing
# grateful
# harvard
# zoom
# recorded
# dame
# gt
# tickets
# authors
# expects
# stores
# martinez
# tea
# guys
# definitely
# less

# %%
for i in set_stops:
    with open("C:\\Users\\User\\Sentiment-Analysis\\src\\main\\Resources\\trainingandtestdata\\stopwords.txt", "a") as output:
        output.write(str(i))
        output.write("\n")
